# %%
import json
with open('/opt/ml/level3_nlp_finalproject-nlp-11/T5/test_preprocessed.json','r') as f:
    data=json.load(f)

# %%
data
# Out:
# {'data': [{'id': 'test_0',
#    'question': 'who got the first nobel prize in physics',
#    'answers': ['Wilhelm Conrad Röntgen']},
#   {'id': 'test_1',
#    'question': 'when is the next deadpool movie being released',
#    'answers': ['May 18 , 2018']},
#   {'id': 'test_2',
#    'question': 'which mode is used for short wave broadcast service',
#    'answers': ['MFSK', 'Olivia']},
#   {'id': 'test_3',
#    'question': 'the south west wind blows across nigeria between',
#    'answers': ['till September']},
#   {'id': 'test_4',
#    'question': 'what does hp mean in war and order',
#    'answers': ['hit points or health points']},
#   {'id': 'test_5',
#    'question': 'who wrote the first declaration of human rights',
#    'answers': ['Cyrus']},
#   {'id': 'test_6',
#    'question': 'who is the owner of reading football club',
#    'answers': ['Yongge Dai', 'Dai Xiuli', 'Dai Yongge', 'Xiu Li Dai']},
#   {'id': 'test_7',
# ...

# %%
questions = []
for item in data['data']:
    questions.append(item['question'])

# %%
questions
# Out:
# ['who got the first nobel prize in physics',
#  'when is the next deadpool movie being released',
#  'which mode is used for short wave broadcast service',
#  'the south west wind blows across nigeria between',
#  'what does hp mean in war and order',
#  'who wrote the first declaration of human rights',
#  'who is the owner of reading football club',
#  'when is the next scandal episode coming out',
#  'when is the last time the philadelphia won the superbowl',
#  'who was the first lady nominated member of the rajya sabha',
#  'what is the most current adobe flash player version',
#  'swan lake the sleeping beauty and the nutcracker are three famous ballets by',
#  'how many episodes are there in dragon ball z',
#  'cast of law & order special victim unit',
#  'who designed the garden city of new earswick',
#  'what is the first step in the evolution of the eye',
#  'where is the tv show the curse of oak island filmed',
#  'where is gall bladder situated in human body',
# ...

# %%
with open("test_questions.json", "w") as json_file:
    json.dump(questions, json_file)
